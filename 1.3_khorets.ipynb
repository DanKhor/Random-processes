# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# По свойству плотности, установим, что C = 1

# %% [markdown]
# <h3>Сгенерируем величину X методом обратной функции, найдя ее распределение

# %%
r1 = stats.uniform.rvs(0, 1, size=5000)
x = (np.sqrt(1 + 8*r) - 1)/2
plt.hist(x)
plt.show()

# %% [markdown]
# <h3>Из условного распредления с помощью метода обратной функции найдем величину Y

# %%
r2 = stats.uniform.rvs(0, 1, size=5000)
y = -x + np.sqrt(x**2 + 2*x*r2 + r2)
plt.hist(y)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(x, y)
ax.set_xlabel('X value')
ax.set_ylabel('Y value')
plt.show()
